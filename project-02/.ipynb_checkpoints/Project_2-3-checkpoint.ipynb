# %% [markdown]
# # Project 2:  Lucid Titanic Sleuthing

# %% [markdown]
# ## Part 1: Developing an understanding of the data

# %% [markdown]
# #### Based on the description of the data you read in the readme describe in your own words this data.

# %% [markdown]
# There are two datasets that represents information about passangers and the crew of two ships, Titanic and Lusitania, and the fate of them, whether they survived or not.

# %% [markdown]
# #### Based on our conceptual understanding of the columns in this data set.  What are the reasonable range of the values for the Sex, Age, SibSp, Parch columns.

# %% [markdown]
# Sex : female and male
# Age: 0 to 80
# Sibsp 0 to 8
# Parch 0 to 9

# %% [markdown]
# ### Open the data in sublime text is there anything that jumps out to you?

# %% [markdown]
# ## Part 2: reading the data in

# %% [markdown]
# #### Now read the data into a Pandas DataFrame

# %%
titanic_data_location = 'assets/titanic.csv'
lusitania_data_location = 'assets/lusitania.csv'
import pandas as pd
import numpy as np
Titanic_df = pd.read_csv(titanic_data_location)
Lusitania_df = pd.read_csv(lusitania_data_location)

# %%
print (Titanic_df.dtypes)
print (Titanic_df.shape)
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object
# (1309, 14)

# %% [markdown]
# #### Check that the age column doesn't have any unreasonable values

# %%
print (Titanic_df['age'].unique())
# Out:
# [ 29.     0.92   2.    30.    25.    48.    63.    39.    53.    71.    47.
#   18.    24.    26.    80.      nan  50.    32.    36.    37.    42.    19.
#   35.    28.    45.    40.    58.    22.    41.    44.    59.    60.    33.
#   17.    11.    14.    49.    76.    46.    27.    64.    55.    70.    38.
#   51.    31.     4.    54.    23.    43.    52.    16.    32.5   21.    15.
#   65.    28.5   45.5   56.    13.    61.    34.     6.    57.    62.    67.
#    1.    12.    20.     0.83   8.     0.67   7.     3.    36.5   18.5    5.
#   66.     9.     0.75  70.5   22.5    0.33   0.17  40.5   10.    23.5   34.5
#   20.5   30.5   55.5   38.5   14.5   24.5   60.5   74.     0.42  11.5   26.5 ]

# %% [markdown]
# There are null values in the age column. It appears that for ages under 1 year, the data is year form which is consistant with the rest of the data.

# %%
print (Lusitania_df['Age'].unique())
# Out:
# ['38' '37' '30' '25' '27' '48' nan '24' '19 ?' '57' '50' '56' '41' '19'
#  '33' '29' '18' '20' '21' '26' '17' '58' '47' '54' '35' '43' '59' '53' '44'
#  '51' '40' '49' '42' '32' '31' '34' '22' '45' '36' '29 ?' '52' '23' '60'
#  '28' '16' '46' '15' '39' '63 ?' '55' '64' '53 ?' '09-months' '6' '9' '14'
#  '10' '12' '?' '62' '5' '8' '65' '68' '76' '61' '63' '03-months' '1.5'
#  '2.5' '18-months' '3' '2' '25 ?' '08-months' '4' '15-months' '14-months'
#  'Infant' '3-6-months ?' '51 or 47' '45 or 51' '22 (?)' '17-months'
#  '13-months' '02-months' '49 ?' '05-months' '11' '59 (64?)' '63 (51?)'
#  '37 (39?)' '32 (22?)' '31 (32?)' '24 (23?)' '27?' '7' '42?' '31 ?'
#  '10-months' '38 (?)' '70' '62 (?)' '06-months' '13' '2_' '11-months'
#  '30 ?' '34?' '1' '39 (47?)' '67' '73' '72' '11-months (3?)' '4.25' '69'
#  '26?' '54?' '21?' '16 ?']

# %% [markdown]
# Lusitania's values under the age column are very messy. In addition to null data it has special characters, word 'month' and some with amb

# %% [markdown]
# #### Check for missing values.  How do you know that a value is missing?

# %%
Titanic_age_is_null = pd.isnull(Titanic_df['age'])
Titanic_missing_ages = Titanic_df[Titanic_age_is_null==True]
Titanic_missing_ages.head()
# Out:
#     pclass  survived                                               name  \
# 15       1         0                                Baumann, Mr. John D
# 37       1         1      Bradley, Mr. George ("George Arthur Brayton")
# 40       1         0                          Brewe, Dr. Arthur Jackson
# 46       1         0                              Cairns, Mr. Alexander
# 59       1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
#
#        sex  age  sibsp  parch    ticket     fare cabin embarked boat  body  \
# 15    male  NaN      0      0  PC 17318  25.9250   NaN        S  NaN   NaN
# 37    male  NaN      0      0    111427  26.5500   NaN        S    9   NaN
# 40    male  NaN      0      0    112379  39.6000   NaN        C  NaN   NaN
# 46    male  NaN      0      0    113798  31.0000   NaN        S  NaN   NaN
# 59  female  NaN      0      0     17770  27.7208   NaN        C    5   NaN
#
#            home.dest
# 15      New York, NY
# 37   Los Angeles, CA
# 40  Philadelphia, PA
# 46               NaN
# 59      New York, NY

# %% [markdown]
# #### Does it makes sense to guess at the value?

# %% [markdown]
# Out of 1308 entries, 263 do not have age information. That is about 20% of the
# data which could potentially throw off the analysis on age. However, guessing
# the age would not be advisable unless we insert the mean of the available data
# for all missing ages.'''

# %% [markdown]
# ## Part 3: data imputation

# %% [markdown]
# #### Well let’s say that it does... You likely noticed that Age has some missing values. How many are missing?

# %%
len(Titanic_missing_ages)
# Out:
# 263

# %% [markdown]
# #### For the Age of the passangers ... how would you guess at the missing values using the other data present in the CSV.

# %%
Titanic_average_age = round(np.mean(Titanic_df['age']), 2)
Titanic_average_age
# Out:
# 29.88

# %%
Titanic_df['age'].fillna(Titanic_average_age, inplace=True)
Titanic_age_is_null = pd.isnull(Titanic_df['age'])
Titanic_missing_ages = Titanic_df[Titanic_age_is_null==True]
print(Titanic_missing_ages.head())
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %% [markdown]
# ## Part 4: Group Statistics

# %% [markdown]
# #### Are there any groups that were especially adversely affected in the Titanic wreck? (justify your response numerically)

# %%
Titanic_df
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#      embarked boat   body                           home.dest
# 0           S    2    NaN                        St Louis, MO
# 1           S   11    NaN     Montreal, PQ / Chesterville, ON
# 2           S  NaN    NaN     Montreal, PQ / Chesterville, ON
# 3           S  NaN  135.0     Montreal, PQ / Chesterville, ON
# 4           S  NaN    NaN     Montreal, PQ / Chesterville, ON
# 5           S    3    NaN                        New York, NY
# 6           S   10    NaN                          Hudson, NY
# 7           S  NaN    NaN                         Belfast, NI
# 8           S    D    NaN                 Bayside, Queens, NY
# 9           C  NaN   22.0                 Montevideo, Uruguay
# 10          C  NaN  124.0                        New York, NY
# 11          C    4    NaN                        New York, NY
# 12          C    9    NaN                       Paris, France
# 13          S    6    NaN                                 NaN
# 14          S    B    NaN                       Hessle, Yorks
# 15          S  NaN    NaN                        New York, NY
# 16          C  NaN    NaN                        Montreal, PQ
# 17          C    6    NaN                        Montreal, PQ
# 18          C    8    NaN                                 NaN
# 19          C    A    NaN                        Winnipeg, MN
# 20          S    5    NaN                        New York, NY
# 21          S    5    NaN                        New York, NY
# 22          C    5    NaN                        New York, NY
# 23          C    4    NaN                                 NaN
# 24          S    8    NaN                                 NaN
# 25          C  NaN  148.0                   San Francisco, CA
# 26          C    7    NaN                        Dowagiac, MI
# 27          C    7    NaN                        Dowagiac, MI
# 28          S    8    NaN                                 NaN
# 29          S    D    NaN  Stockholm, Sweden / Washington, DC
# ...       ...  ...    ...                                 ...
# 1279        S  NaN    NaN                                 NaN
# 1280        S  NaN    NaN                                 NaN
# 1281        S  NaN    NaN      Antwerp, Belgium / Stanton, OH
# 1282        S  NaN    NaN                                 NaN
# 1283        S  NaN    NaN                                 NaN
# 1284        S  NaN    NaN                                 NaN
# 1285        S  NaN  298.0                                 NaN
# 1286        C    C    NaN                                 NaN
# 1287        S  NaN    NaN                                 NaN
# 1288        S  NaN  314.0                                 NaN
# 1289        S  NaN    NaN                                 NaN
# 1290        S  NaN    NaN                                 NaN
# 1291        S  NaN    NaN                                 NaN
# 1292        S  NaN    NaN                                 NaN
# 1293        S  NaN    NaN                                 NaN
# 1294        S  NaN   14.0                                 NaN
# 1295        S  NaN    NaN                                 NaN
# 1296        S  NaN  131.0                                 NaN
# 1297        S  NaN    NaN                                 NaN
# 1298        S  NaN    NaN                                 NaN
# 1299        C    C    NaN                                 NaN
# 1300        C  NaN    NaN                                 NaN
# 1301        C  NaN  312.0                                 NaN
# 1302        C  NaN    NaN                                 NaN
# 1303        C  NaN    NaN                                 NaN
# 1304        C  NaN  328.0                                 NaN
# 1305        C  NaN    NaN                                 NaN
# 1306        C  NaN  304.0                                 NaN
# 1307        C  NaN    NaN                                 NaN
# 1308        S  NaN    NaN                                 NaN
#
# [1309 rows x 14 columns]

# %%
Age_group = []
for x in Titanic_df['age']:
    if x == 29.88:
        Age_group.append('unkown')
    else:
        if x <= 6:
            Age_group.append('child')
        if x > 6 and x <=17:
            Age_group.append('young')    
        if x > 17 and x <=60:
            Age_group.append('adult')    
        if x > 60:
            Age_group.append('senior')  
Titanic_df['age group'] = Age_group
Titanic_df.head(20)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
# 15       1         0                                Baumann, Mr. John D
# 16       1         0                           Baxter, Mr. Quigg Edmond
# 17       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18       1         1                              Bazzani, Miss. Albina
# 19       1         0                               Beattie, Mr. Thomson
#
#        sex    age  sibsp  parch    ticket      fare    cabin embarked boat  \
# 0   female  29.00      0      0     24160  211.3375       B5        S    2
# 1     male   0.92      1      2    113781  151.5500  C22 C26        S   11
# 2   female   2.00      1      2    113781  151.5500  C22 C26        S  NaN
# 3     male  30.00      1      2    113781  151.5500  C22 C26        S  NaN
# 4   female  25.00      1      2    113781  151.5500  C22 C26        S  NaN
# 5     male  48.00      0      0     19952   26.5500      E12        S    3
# 6   female  63.00      1      0     13502   77.9583       D7        S   10
# 7     male  39.00      0      0    112050    0.0000      A36        S  NaN
# 8   female  53.00      2      0     11769   51.4792     C101        S    D
# 9     male  71.00      0      0  PC 17609   49.5042      NaN        C  NaN
# 10    male  47.00      1      0  PC 17757  227.5250  C62 C64        C  NaN
# 11  female  18.00      1      0  PC 17757  227.5250  C62 C64        C    4
# 12  female  24.00      0      0  PC 17477   69.3000      B35        C    9
# 13  female  26.00      0      0     19877   78.8500      NaN        S    6
# 14    male  80.00      0      0     27042   30.0000      A23        S    B
# 15    male  29.88      0      0  PC 17318   25.9250      NaN        S  NaN
# 16    male  24.00      0      1  PC 17558  247.5208  B58 B60        C  NaN
# 17  female  50.00      0      1  PC 17558  247.5208  B58 B60        C    6
# 18  female  32.00      0      0     11813   76.2917      D15        C    8
# 19    male  36.00      0      0     13050   75.2417       C6        C    A
#
#      body                        home.dest age group
# 0     NaN                     St Louis, MO     adult
# 1     NaN  Montreal, PQ / Chesterville, ON     child
# 2     NaN  Montreal, PQ / Chesterville, ON     child
# 3   135.0  Montreal, PQ / Chesterville, ON     adult
# 4     NaN  Montreal, PQ / Chesterville, ON     adult
# 5     NaN                     New York, NY     adult
# 6     NaN                       Hudson, NY    senior
# 7     NaN                      Belfast, NI     adult
# 8     NaN              Bayside, Queens, NY     adult
# 9    22.0              Montevideo, Uruguay    senior
# 10  124.0                     New York, NY     adult
# 11    NaN                     New York, NY     adult
# 12    NaN                    Paris, France     adult
# 13    NaN                              NaN     adult
# 14    NaN                    Hessle, Yorks    senior
# 15    NaN                     New York, NY    unkown
# 16    NaN                     Montreal, PQ     adult
# 17    NaN                     Montreal, PQ     adult
# 18    NaN                              NaN     adult
# 19    NaN                     Winnipeg, MN     adult

# %%
Tit_pivot_age_sex_effect = pd.pivot_table(Titanic_df, values=['survived'],columns=['sex'],\
                                          index=['age group'],aggfunc=[sum,len],margins=True)
Tit_pivot_age_sex_effect['Female Survival Ratio %'] = ((Tit_pivot_age_sex_effect['sum'])\
                                                     ['survived'])['female']*100/((Tit_pivot_age_sex_effect['len'])\
                                                                                  ['survived'])['female']
Tit_pivot_age_sex_effect['Male Survival Ratio %'] = ((Tit_pivot_age_sex_effect['sum'])\
                                                     ['survived'])['male']*100/((Tit_pivot_age_sex_effect['len'])\
                                                                                  ['survived'])['male']
Tit_pivot_age_sex_effect['Age Group Survival Ratio %'] = ((Tit_pivot_age_sex_effect['sum'])\
                                                     ['survived'])['All']*100/((Tit_pivot_age_sex_effect['len'])\
                                                                                  ['survived'])['All']
Tit_pivot_age_sex_effect
# Out:
#                sum                    len                 \
#           survived               survived
# sex         female   male    All   female   male     All
# age group
# adult        236.0  102.0  338.0    309.0  550.0   859.0
# child         21.0   19.0   40.0     30.0   32.0    62.0
# senior         6.0    2.0    8.0      7.0   26.0    33.0
# unkown        47.0   26.0   73.0     78.0  185.0   263.0
# young         29.0   12.0   41.0     42.0   50.0    92.0
# All          339.0  161.0  500.0    466.0  843.0  1309.0
#
#           Female Survival Ratio % Male Survival Ratio %  \
#
# sex
# age group
# adult                   76.375405             18.545455
# child                   70.000000             59.375000
# senior                  85.714286              7.692308
# unkown                  60.256410             14.054054
# young                   69.047619             24.000000
# All                     72.746781             19.098458
#
#           Age Group Survival Ratio %
#
# sex
# age group
# adult                      39.348079
# child                      64.516129
# senior                     24.242424
# unkown                     27.756654
# young                      44.565217
# All                        38.197097

# %%
Tit_pivot_class_effect = pd.pivot_table(Titanic_df, values=['survived'],index=['pclass'],\
                                          aggfunc=[sum,len],margins=True)
Tit_pivot_class_effect['Class Survival Ratio %'] = (Tit_pivot_class_effect['sum'])\
                                                     ['survived']*100/(Tit_pivot_class_effect['len'])\
                                                                                  ['survived']
Tit_pivot_class_effect
# Out:
#             sum      len Class Survival Ratio %
#        survived survived
# pclass
# 1         200.0    323.0              61.919505
# 2         119.0    277.0              42.960289
# 3         181.0    709.0              25.528914
# All       500.0   1309.0              38.197097

# %% [markdown]
# it seams that better class (lower class number) has a positive corrolation with survival ratio

# %% [markdown]
# #### Are there any groups that outperformed the survival of the latter group? (justify your response numerically)

# %% [markdown]
# ## Part 5:  Comparative Statistics:  Lusitania

# %% [markdown]
# #### Are there any groups that were especially adversely affected in the Titanic wreck? (justify your response numerically)

# %%
Lusitania_df
# Out:
#      Family name       Title       Personal name   Fate   Age  \
# 0        CAMERON         Mr.          Charles W.   Lost    38
# 1     CARR-JONES         Mr.                  E.   Lost    37
# 2      DRAKEFORD         Mr.              Edward  Saved    30
# 1958      WRIGHT  Master (?)       Harold Joseph   Lost   NaN
# 1959       WYNNE      Master              George  Saved    16
# 1960       WYNNE        Mr.       Joseph Dominic   Lost    37
#
#      Department/Class Passenger/Crew      Citizenship  \
# 0                Band           Crew          British
# 1                Band           Crew          British
# 2                Band           Crew          British
# 3                Band           Crew          British
# 4                Band           Crew          British
# 5                Deck           Crew          British
# 6                Deck           Crew        Norwegian
# 7                Deck           Crew  British (Irish)
# 8                Deck           Crew  British (Irish)
# 9                Deck           Crew          British
# 10               Deck           Crew          British
# 11               Deck           Crew          British
# 12               Deck           Crew          British
# 13               Deck           Crew          British
# 14               Deck           Crew          British
# 15               Deck           Crew          British
# 16               Deck           Crew          British
# 17               Deck           Crew          British
# 18               Deck           Crew          British
# 19               Deck           Crew          British
# 20               Deck           Crew          British
# 21               Deck           Crew          British
# 22               Deck           Crew          British
# 23               Deck           Crew  British (Irish)
# 24               Deck           Crew          British
# 25               Deck           Crew  British (Irish)
# 26               Deck           Crew          British
# 27               Deck           Crew  British (Irish)
# 28               Deck           Crew          British
# 29               Deck           Crew          British
# ...               ...            ...              ...
# 1931      Victualling           Crew          British
# 1932      Victualling           Crew          British
# 1933      Victualling           Crew          British
# 1934      Victualling           Crew          British
# 1935      Victualling           Crew          British
# 1936      Victualling           Crew          Spanish
# 1937      Victualling           Crew            Dutch
# 1938      Victualling           Crew          British
# 1939      Victualling           Crew          British
# 1940      Victualling           Crew          British
# 1941      Victualling           Crew          British
# 1942      Victualling           Crew          British
# 1943      Victualling           Crew          British
# 1944      Victualling           Crew          British
# 1945      Victualling           Crew          British
# 1946      Victualling           Crew          British
# 1947      Victualling           Crew          British
# 1948      Victualling           Crew          British
# 1949      Victualling           Crew          British
# 1950      Victualling           Crew          British
# 1951      Victualling           Crew          British
# 1952      Victualling           Crew          British
# 1953      Victualling           Crew          British
# 1954      Victualling           Crew          British
# 1955      Victualling           Crew          British
# 1956      Victualling           Crew          British
# 1957      Victualling           Crew          British
# 1958      Victualling           Crew          British
# 1959      Victualling           Crew          British
# 1960      Victualling           Crew          British
#
#                                Position  Status   ...    Country  \
# 0                                   NaN     NaN   ...        NaN
# 1                                   NaN     NaN   ...        NaN
# 2                                Violin     NaN   ...        NaN
# 3                                 Cello     NaN   ...        NaN
# 4                           Double Bass     NaN   ...        NaN
# 5                         Staff Captain     NaN   ...    England
# 6                    Able-Bodied Seaman     NaN   ...        NaN
# 7                    Able-Bodied Seaman     NaN   ...    Ireland
# 8                  Junior Third Officer  Single   ...    Ireland
# 9                    Able-Bodied Seaman     NaN   ...        NaN
# 10                               Joiner     NaN   ...        NaN
# 11                            Inspector     NaN   ...        NaN
# 12                   Able-Bodied Seaman     NaN   ...        NaN
# 13                   Able-Bodied Seaman     NaN   ...        NaN
# 14                       Baggage Master     NaN   ...        NaN
# 15                   Able-Bodied Seaman     NaN   ...        NaN
# 16                            Boatswain     NaN   ...        NaN
# 17                     Boatswain's Mate     NaN   ...        NaN
# 18                   Able-Bodied Seaman     NaN   ...        NaN
# 19                   Able-Bodied Seaman     NaN   ...        NaN
# 20                   Able-Bodied Seaman     NaN   ...        NaN
# 21                   Able-Bodied Seaman     NaN   ...        NaN
# 22                   Able-Bodied Seaman     NaN   ...        NaN
# 23                    Assistant Surgeon     NaN   ...    Ireland
# 24                   Able-Bodied Seaman     NaN   ...        NaN
# 25                   Able-Bodied Seaman     NaN   ...    Ireland
# 26                       Second Officer     NaN   ...        NaN
# 27                   Able-Bodied Seaman     NaN   ...    Ireland
# 28                   Able-Bodied Seaman     NaN   ...        NaN
# 29                   Able-Bodied Seaman     NaN   ...        NaN
# ...                                 ...     ...   ...        ...
# 1931     Second Cabin Cabin Bed Steward     NaN   ...        NaN
# 1932   Assistant Officers' Mess Steward     NaN   ...        NaN
# 1933                      Second Waiter     NaN   ...        NaN
# 1934                       First Waiter     NaN   ...        NaN
# 1935           Assistant Pantry Steward     NaN   ...        NaN
# 1936                         Sauce Cook     NaN   ...        NaN
# 1937                       First Waiter     NaN   ...        NaN
# 1938                             Waiter     NaN   ...        NaN
# 1939                        Sculleryman     NaN   ...        NaN
# 1940                      Second Waiter     NaN   ...        NaN
# 1941                             Waiter     NaN   ...        NaN
# 1942                         Stewardess     NaN   ...        NaN
# 1943                       Third Waiter     NaN   ...        NaN
# 1944                       Deck Steward     NaN   ...        NaN
# 1945            Engineers� Mess Steward     NaN   ...        NaN
# 1946                       Third Waiter     NaN   ...        NaN
# 1947                      Second Waiter     NaN   ...        NaN
# 1948                     Night Watchman     NaN   ...        NaN
# 1949                       First Waiter     NaN   ...        NaN
# 1950           Saloon Cabin Bed Steward     NaN   ...        NaN
# 1951                     Pantry Steward     NaN   ...        NaN
# 1952                       First Waiter     NaN   ...        NaN
# 1953                       Second Baker     NaN   ...        NaN
# 1954           Saloon Cabin Bed Steward     NaN   ...        NaN
# 1955           Assistant Pantry Steward     NaN   ...        NaN
# 1956           Saloon Cabin Bed Steward     NaN   ...        NaN
# 1957  Barkeeper, Smokeroom Second Cabin     NaN   ...        NaN
# 1958                      Steward's Boy     NaN   ...        NaN
# 1959                     Assistant Cook     NaN   ...    England
# 1960                        Sculleryman     NaN   ...    England
#
#             Lifeboat          Rescue Vessel Body No. Ticket No. Cabin No.  \
# 0                NaN                    NaN      NaN        NaN       NaN
# 1                NaN                    NaN      NaN        NaN       NaN
# 2                NaN                    NaN      NaN        NaN       NaN
# 3                NaN                    NaN      NaN        NaN       NaN
# 4                NaN                    NaN      NaN        NaN       NaN
# 5                NaN                    NaN       48        NaN       NaN
# 6                NaN                    NaN      NaN        NaN       NaN
# 7     3 collapsibles  Westborough (Katrina)      NaN        NaN       NaN
# 8        collapsible               Bluebell      NaN        NaN       NaN
# 9                NaN                    NaN      NaN        NaN       NaN
# 10               NaN                    NaN      NaN        NaN       NaN
# 11               NaN                    NaN      176        NaN       NaN
# 12               NaN                    NaN      NaN        NaN       NaN
# 13               NaN                    NaN      NaN        NaN       NaN
# 14               NaN                    NaN      NaN        NaN       NaN
# 15               NaN                    NaN      NaN        NaN       NaN
# 22                                                  NaN     1       Adult
# 23                                                  NaN     1       Adult
# 24                                                  NaN     1       Adult
# 25                                                  NaN     1       Adult
# 26                                                  NaN     1       Adult
# 27                                                  NaN     1       Adult
# 28                                                  NaN     1       Adult
# 29                                                  NaN     1       Adult
# ...                                                 ...   ...         ...
# 1931                                                NaN     1       Adult
# 1932                                                NaN     1       Adult
# 1933                                                NaN     1       Adult
# 1934                                                NaN     1       Adult
# 1935                                                NaN     1       Adult
# 1936                                                NaN     1       Adult
# 1937                                                NaN     1       Adult
# 1938                                                NaN     1       Adult
# 1939                                                NaN     1       Adult
# 1940                                                NaN     1       Adult
# 1941                                                NaN     1       Adult
# 1942                                                NaN     1       Adult
# 1943                                                NaN     1       Adult
# 1944                                                NaN     1       Adult
# 1945                                                NaN     1       Adult
# 1946                                                NaN     1       Adult
# 1947                                                NaN     1       Adult
# 1948                                                NaN     1       Adult
# 1949                                                NaN     1       Adult
# 1950                                                NaN     1       Adult
# 1951                                                NaN     1       Adult
# 1952                                                NaN     1       Adult
# 1953                                                NaN     1       Adult
# 1954                                                NaN     1       Adult
# 1955                           Buried in Common Grave B     1       Adult
# 1956                                                NaN     1       Adult
# 1957                                                NaN     1       Adult
# 1958                                                NaN     1      Minor?
# 1959  George was assistant cook in first class. Age ...     1       Minor
# 1960  Joseph was George�s father. Suffered from bron...     1       Adult
#
#          Sex
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
# 5       Male
# 6       Male
# 7       Male
# 8       Male
# 9       Male
# 10      Male
# 11      Male
# 12      Male
# 13      Male
# 14      Male
# 15      Male
# 16      Male
# 17      Male
# 18      Male
# 19      Male
# 20      Male
# 21      Male
# 22      Male
# 23      Male
# 24      Male
# 25      Male
# 26      Male
# 27      Male
# 28      Male
# 29      Male
# ...      ...
# 1931    Male
# 1932    Male
# 1933    Male
# 1934    Male
# 1935    Male
# 1936    Male
# 1937    Male
# 1938    Male
# 1939    Male
# 1940    Male
# 1941    Male
# 1942  Female
# 1943    Male
# 1944    Male
# 1945    Male
# 1946    Male
# 1947    Male
# 1948    Male
# 1949    Male
# 1950    Male
# 1951    Male
# 1952    Male
# 1953    Male
# 1954    Male
# 1955    Male
# 1956    Male
# 1957    Male
# 1958    Male
# 1959    Male
# 1960    Male
#
# [1961 rows x 23 columns]

# %%
print (Lusitania_df.dtypes)
print (Lusitania_df.shape)
# Out:
# Family name                             object
# Title                                   object
# Personal name                           object
# Fate                                    object
# Age                                     object
# Department/Class                        object
# Passenger/Crew                          object
# Citizenship                             object
# Position                                object
# Status                                  object
# City                                    object
# County                                  object
# State                                   object
# Country                                 object
# Lifeboat                                object
# Rescue Vessel                           object
# Body No.                                object
# Ticket No.                              object
# Cabin No.                               object
# Traveling Companions and other notes    object
# Value                                    int64
# Adult/Minor                             object
# Sex                                     object
# dtype: object
# (1961, 23)

# %%
print type(Lusitania_df['Age'])
print (Lusitania_df['Age'].unique())
# Out:
# <class 'pandas.core.series.Series'>
# ['38' '37' '30' '25' '27' '48' nan '24' '19 ?' '57' '50' '56' '41' '19'
#  '33' '29' '18' '20' '21' '26' '17' '58' '47' '54' '35' '43' '59' '53' '44'
#  '51' '40' '49' '42' '32' '31' '34' '22' '45' '36' '29 ?' '52' '23' '60'
#  '28' '16' '46' '15' '39' '63 ?' '55' '64' '53 ?' '09-months' '6' '9' '14'
#  '10' '12' '?' '62' '5' '8' '65' '68' '76' '61' '63' '03-months' '1.5'
#  '2.5' '18-months' '3' '2' '25 ?' '08-months' '4' '15-months' '14-months'
#  'Infant' '3-6-months ?' '51 or 47' '45 or 51' '22 (?)' '17-months'
#  '13-months' '02-months' '49 ?' '05-months' '11' '59 (64?)' '63 (51?)'
#  '37 (39?)' '32 (22?)' '31 (32?)' '24 (23?)' '27?' '7' '42?' '31 ?'
#  '10-months' '38 (?)' '70' '62 (?)' '06-months' '13' '2_' '11-months'
#  '30 ?' '34?' '1' '39 (47?)' '67' '73' '72' '11-months (3?)' '4.25' '69'
#  '26?' '54?' '21?' '16 ?']

# %%
extra_characters = [' \?', ' \(...\)?', ' \(.\)?', ' .. ..', '\_', '\?']
for ch in extra_characters:
    Lusitania_df['Age'] = Lusitania_df.Age.str.replace(ch,'')
Lusitania_df['Age'] = Lusitania_df.Age.str.replace('..-months','1')
Lusitania_df['Age'] = Lusitania_df.Age.replace('Infant','1')
Lusitania_df['Age'] = Lusitania_df.Age.replace(str(''), np.nan)
print (Lusitania_df['Age'].unique())
# Out:
# ['38' '37' '30' '25' '27' '48' nan '24' '19' '57' '50' '56' '41' '33' '29'
#  '18' '20' '21' '26' '17' '58' '47' '54' '35' '43' '59' '53' '44' '51' '40'
#  '49' '42' '32' '31' '34' '22' '45' '36' '52' '23' '60' '28' '16' '46' '15'
#  '39' '63' '55' '64' '1' '6' '9' '14' '10' '12' '62' '5' '8' '65' '68' '76'
#  '61' '1.5' '2.5' '3' '2' '4' '11' '7' '70' '13' '67' '73' '72' '4.25' '69']

# %%
Lusi_pivot_sex_effect = pd.pivot_table(Titanic_df, values=['Fate'],columns=['Sex'],\
                                          index=['Fate'],aggfunc=[len],margins=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-7ae6a79d7e5a> in <module>()
# ----> 1 Lusi_pivot_sex_effect = pd.pivot_table(Titanic_df, values=['Fate'],columns=['Sex'],                                          index=['Fate'],aggfunc=[len],margins=True)
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/tools/pivot.pyc in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      87                                 columns=columns,
#      88                                 fill_value=fill_value, aggfunc=func,
# ---> 89                                 margins=margins, margins_name=margins_name)
#      90             pieces.append(table)
#      91             keys.append(func.__name__)
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/tools/pivot.pyc in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#     118             data = data[to_filter]
#     119
# --> 120     grouped = data.groupby(keys)
#     121     agged = grouped.agg(aggfunc)
#     122
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    3972         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    3973                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 3974                        **kwargs)
#    3975
#    3976     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/groupby.pyc in groupby(obj, by, **kwds)
#    1499         raise TypeError('invalid type: %s' % type(obj))
#    1500
# -> 1501     return klass(obj, by, **kwds)
#    1502
#    1503
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/groupby.pyc in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     368                                                     level=level,
#     369                                                     sort=sort,
# --> 370                                                     mutated=self.mutated)
#     371
#     372         self.obj = obj
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/groupby.pyc in _get_grouper(obj, key, axis, level, sort, mutated)
#    2471
#    2472         elif is_in_axis(gpr):  # df.groupby('name')
# -> 2473             in_axis, name, gpr = True, gpr, obj[gpr]
#    2474             exclusions.append(name)
#    2475
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2055             return self._getitem_multilevel(key)
#    2056         else:
# -> 2057             return self._getitem_column(key)
#    2058
#    2059     def _getitem_column(self, key):
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2062         # get column
#    2063         if self.columns.is_unique:
# -> 2064             return self._get_item_cache(key)
#    2065
#    2066         # duplicate columns & possible reduce dimensionality
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3518
#    3519             if not isnull(item):
# -> 3520                 loc = self.items.get_loc(item)
#    3521             else:
#    3522                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2104                 return self._engine.get_loc(key)
#    2105             except KeyError:
# -> 2106                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2107
#    2108         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4160)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4024)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13161)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13115)()
#
# KeyError: 'Fate'

# %%
Lusitania_df.Fate.unique()
# Out:
# array(['Lost', 'Saved', 'Saved (died from trauma)', 'Not on board'], dtype=object)

# %%
Lusitania_df['Age_temp'] = Lusitania_df['Age'].astype(float)
Age_group = []

# %%
# for x in Lusitania_df['Age_temp'].astype(float):
#     if x == np.nan:
#         b = 'unkown'
#     if x <= 6:
#         b = 'child'
#     if x > 6 and x <=17:
#         b = 'young'
#     if x > 17 and x <=60:
#         b = 'adult'
#     if x > 60:
#         c = 'senior'
#     Age_group.append(b)
# print (Age_group)

# %% [markdown]
# #### Are there any groups that outperformed the survival of the latter group? (justify your response numerically)

# %% [markdown]
# #### What does the group-wise survival rate imply about circumstances during these two accidents?
