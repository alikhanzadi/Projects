# %%
import pandas as pd
import numpy as np
data = pd.read_csv('../assets/indeed-scraped-job-postings.csv')
data
# Out:
#               city                                     company  \
# 0           Denver                  Department Of The Interior
# 1           Denver                  Department Of The Interior
# 2           Denver              Mental Health Center of Denver
# 3           Denver                       Denver Public Schools
# 4           Denver                      University of Colorado
# 5           Denver                               Denver Health
# 6           Denver                               Denver Health
# 7           Denver                               Denver Health
# 8           Denver                      University of Colorado
# 9           Denver                  Computer Enterprises, Inc.
# 10          Denver                                Potatoes USA
# 11          Denver                  Department Of The Interior
# 12          Denver                      University of Colorado
# 13          Denver                      University of Colorado
# ...

# %%
pd.options.display.max_seq_items = 2000

# %%
for x in data.title:
    print x
# Out:
# Statistician, GS-1350-12 (DEU-PERM-DS)
# Interdisciplinary Cartographer/Geographer - GS-1370/0150-12...
# Financial Data Scientist
# SENIOR RESEARCH ANALYST
# Animal Care I
# Assistant Research Scientist - RADARS
# Statistical Research Specialist
# Statistical Research Scientist - RADARS
# Regulatory & Compliance Manager
# Software Engineer/Data Scientist
# Global Marketing Manager - Ingredient and School Foodservice
# Geologist GS-1350-07/09 (DEU - TERM - JG)
# Professional Research Assistant - Data Manager
# Professional Research Assistant - Tissue Bank Coordinator/Da...
# Platform Developer/Geospatial Big Data (Python)
# Professional Research Assistant - Clinical Research Coordina...
# DevOps Engineer
# Data Scientist Programmer/Specialist
# Senior Deep Learning Data Scientist
# Robotics software engineer (involves machine learning, AI, a...
# Research Analyst/Customer Serv
# Data Scientist
# International Environmental Specialist
# ...
