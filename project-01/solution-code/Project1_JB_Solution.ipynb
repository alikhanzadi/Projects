# %% [markdown]
# # Project 1

# %% [markdown]
# ## Step 1: Open the `sat_scores.csv` file using sublime text. Investigate the data, and answer the questions below.

# %% [markdown]
# ##### 1. What does the data describe?

# %% [markdown]
# SAT Math and Verbal scores, and participation rates, for 50 United States, plus Washington DC for the year 2001. It should be noted that the Math and Verbal scores are an average over the entire state of interest. Additionally, 'participation rate' is ambiguous as we are told the details of how this is calculated (Does it refer to all students of a certain age across the country? All graduates?).

# %% [markdown]
# ##### 2. Does the data look complete? Are there any obvious issues with the observations?

# %% [markdown]
# Data looks good, no missing values. Furthermore, the values for SAT scores and participation look reasonable. Specifically, we know that SAT scores range from math (200-800) and verbal (200-800) therefore we would know that a value outside of this range would be erroneous.
#
# Also important to note, is that the last row of the data set is an average of the other values. We recognise this row is not data for a state named ‘all’. We will remove this row when doing our analysis.

# %% [markdown]
# #### 3. Create a data dictionary for the dataset.

# %% [markdown]
# State - string - The geographic location from which the data was collected.
#
# Rate - integer - The percentage of students who took the SAT out of (presumably) all of the students elagable to take the SAT.
#
# Math - integer - The average score, 200 - 800, on the math section of the SAT.
#
# Verbal - integer - The average score, 200 - 800, on the verbal section of the SAT.

# %% [markdown]
# ## Step 2: Load the data.

# %% [markdown]
# ##### 3. Load the data into a list of lists

# %%
data= []
with open('sat_scores.csv') as f:
    for line in f:
        data.append(line.strip().split(','))

# %% [markdown]
# ##### 4. Print the data

# %%
data
# Out:
# [['State', 'Rate', 'Verbal', 'Math'],
#  ['CT', '82', '509', '510'],
#  ['NJ', '81', '499', '513'],
#  ['MA', '79', '511', '515'],
#  ['NY', '77', '495', '505'],
#  ['NH', '72', '520', '516'],
#  ['RI', '71', '501', '499'],
#  ['PA', '71', '500', '499'],
#  ['VT', '69', '511', '506'],
#  ['ME', '69', '506', '500'],
#  ['VA', '68', '510', '501'],
#  ['DE', '67', '501', '499'],
#  ['MD', '65', '508', '510'],
#  ['NC', '65', '493', '499'],
#  ['GA', '63', '491', '489'],
#  ['IN', '60', '499', '501'],
#  ['SC', '57', '486', '488'],
#  ['DC', '56', '482', '474'],
#  ['OR', '55', '526', '526'],
#  ['FL', '54', '498', '499'],
#  ['WA', '53', '527', '527'],
#  ['TX', '53', '493', '499'],
#  ['HI', '52', '485', '515'],
#  ['AK', '51', '514', '510'],
#  ['CA', '51', '498', '517'],
#  ['AZ', '34', '523', '525'],
#  ['NV', '33', '509', '515'],
#  ['CO', '31', '539', '542'],
#  ['OH', '26', '534', '439'],
#  ['MT', '23', '539', '539'],
#  ['WV', '18', '527', '512'],
# ...

# %% [markdown]
# ##### 5. Extract a list of the labels from the data, and remove them from the data.

# %%
del data[-1]# remove the last line

# %%
header = data[0]# get the header

# %%
del data[0]# and remove the header

# %% [markdown]
# ##### 6. Create a list of State names extracted from the data. (Hint: use the list of labels to index on the State column)

# %%
state_names = [row[0] for row in data]

# %% [markdown]
# ##### 7. Print the types of each column

# %%
for item in data[0]:
    print type(item)
# Out:
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>

# %% [markdown]
# ##### 8. Do any types need to be reassigned? If so, go ahead and do it.

# %% [markdown]
# Yes we need to name the scores and the rate for each state into intagers

# %%
data_as_int = []
for ii, row in enumerate(data):
    data_as_int.append([row[0]])
    for item in row[1:]:
        data_as_int[ii].append(int(item))

# %%
data_as_int
# Out:
# [['CT', 82, 509, 510],
#  ['NJ', 81, 499, 513],
#  ['MA', 79, 511, 515],
#  ['NY', 77, 495, 505],
#  ['NH', 72, 520, 516],
#  ['RI', 71, 501, 499],
#  ['PA', 71, 500, 499],
#  ['VT', 69, 511, 506],
#  ['ME', 69, 506, 500],
#  ['VA', 68, 510, 501],
#  ['DE', 67, 501, 499],
#  ['MD', 65, 508, 510],
#  ['NC', 65, 493, 499],
#  ['GA', 63, 491, 489],
#  ['IN', 60, 499, 501],
#  ['SC', 57, 486, 488],
#  ['DC', 56, 482, 474],
#  ['OR', 55, 526, 526],
#  ['FL', 54, 498, 499],
#  ['WA', 53, 527, 527],
#  ['TX', 53, 493, 499],
#  ['HI', 52, 485, 515],
#  ['AK', 51, 514, 510],
#  ['CA', 51, 498, 517],
#  ['AZ', 34, 523, 525],
#  ['NV', 33, 509, 515],
#  ['CO', 31, 539, 542],
#  ['OH', 26, 534, 439],
#  ['MT', 23, 539, 539],
#  ['WV', 18, 527, 512],
#  ['ID', 17, 543, 542],
#  ['TN', 13, 562, 553],
#  ['NM', 13, 551, 542],
#  ['IL', 12, 576, 589],
#  ['KY', 12, 550, 550],
#  ['WY', 11, 547, 545],
#  ['MI', 11, 561, 572],
#  ['MN', 9, 580, 589],
#  ['KS', 9, 577, 580],
#  ['AL', 9, 559, 554],
# ...

# %% [markdown]
# ##### 9. Create a dictionary for each column mapping the State to its respective value for that column.

# %%
# i;m going to do this in two ways
# first as three dicts
state_rate = {}
state_math = {}
state_verbal = {}

for row in data_as_int:
    state_rate[row[0]] = row[1]
    state_verbal[row[0]] = row[2]
    state_math[row[0]] = row[3]

# %%
# now as one dict

state_data = {}
for row in data_as_int:
    state_data[row[0]] = row[1:]

# %% [markdown]
# ##### 10. Create a dictionary with the values for each of the numeric columns

# %%
# i'm going to do this in two ways
# first as a for loop

# %%
# now as a comp...
data_dict = {'rate': [row[1] for row in data_as_int],
             'math': [row[3] for row in data_as_int],
             'verbal': [row[2] for row in data_as_int]
            }

# %%
data_dict
# Out:
# {'math': [510,
#   513,
#   515,
#   505,
#   516,
#   499,
#   499,
#   506,
#   500,
#   501,
#   499,
#   510,
#   499,
#   489,
#   501,
#   488,
#   474,
#   526,
#   499,
#   527,
#   499,
#   515,
#   510,
#   517,
#   525,
#   515,
#   542,
#   439,
#   539,
#   512,
#   542,
#   553,
#   542,
#   589,
#   550,
#   545,
#   572,
#   589,
#   580,
#   554,
#   568,
#   561,
#   577,
#   562,
#   596,
#   550,
#   570,
#   603,
#   582,
#   599,
#   551],
#  'rate': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'verbal': [509,
#   499,
#   511,
#   495,
#   520,
#   501,
#   500,
#   511,
#   506,
#   510,
#   501,
#   508,
#   493,
# ...

# %% [markdown]
# ## Step 3: Describe the data

# %% [markdown]
# ##### 11. Print the min and max of each column

# %%
print 'Rate:'
print ' - min:', min(data_dict['rate'])
print ' - max:', max(data_dict['rate'])

print 'Math:'
print ' - min:', min(data_dict['math'])
print ' - max:', max(data_dict['math'])

print 'Verbal:'
print ' - min:', min(data_dict['verbal'])
print ' - max:', max(data_dict['verbal'])
# Out:
# Rate:
#  - min: 4
#  - max: 82
# Math:
#  - min: 439
#  - max: 603
# Verbal:
#  - min: 482
#  - max: 593

# %% [markdown]
# ##### 12. Write a function using only list comprehensions, no loops, to compute Standard Deviation. Print the Standard Deviation of each numeric column.

# %%
def my_avg(x):
    return sum(x)*1.0/len(x)


def my_std(x):
    avg = my_avg(x)
    return (sum([(elm-avg)**2 for elm in x])/len(x))**0.5

# %%
    
print 'Rate:', my_std(data_dict['rate'])
print 'Math:', my_std(data_dict['math'])
print 'Verbal:', my_std(data_dict['verbal'])
# Out:
# Rate: 27.2792386761
# Math: 35.9298731731
# Verbal: 33.0319826842

# %% [markdown]
# ## Step 4: Visualize the data

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline


# %matplotlib inline
import matplotlib.pyplot as plt
# facecolor='red'
plt.hist(data_dict['rate'], bins=10)
plt.xlabel('Scores')
plt.ylabel('Frequency')
plt.title('Distribution of the Rate')
plt.show()
# Out:
# /Users/jason/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radiuses

plt.scatter(x, y, area, colors, alpha=0.5)
plt.xlabel('this is the x axis')
plt.ylabel('this is the y axis')
plt.title('this is the title')
plt.show()

# %% [markdown]
# This above was included just as an example of scatter plot

# %% [markdown]
# ##### 14. Plot the Math distribution

# %%
plt.hist(data_dict['math'], 40, facecolor='green', alpha=0.75,range=[400,650])
plt.xlabel('Scores')
plt.ylabel('Frequency')
plt.title('Distribution of the Math scores')
plt.show()

# %% [markdown]
# ##### 15. Plot the Verbal distribution

# %%
plt.hist(data_dict['verbal'], 40, facecolor='green', alpha=0.75,range=[400,650])
plt.xlabel('Scores')
plt.ylabel('Frequency')
plt.title('Distribution of the Verbal scores')
plt.show()

# %% [markdown]
# Interestingly this data looks bimodal.

# %% [markdown]
# ##### 16. What is the typical assumption for data distribution?

# %% [markdown]
# We assume the distribution is normal. (more info here: http://stats.stackexchange.com/questions/116550/why-do-we-have-to-assume-normality-for-a-one-sample-t-test)

# %% [markdown]
# ##### 17. Does that distribution appear to hold true for our data?

# %% [markdown]
# Nope

# %% [markdown]
# ##### 18. Plot some scatterplots. **BONUS**: Use a PyPlot `figure` to present multiple plots at once.

# %%
fig = plt.figure(figsize=(15,6))

ax1 = fig.add_subplot(131)
plt.scatter(data_dict['rate'],data_dict['verbal'], color = 'b')
ax1.set_xlabel('Rate')
plt.grid(True)
ax1.set_ylabel('Verbal')

ax2 = fig.add_subplot(132)
plt.scatter(data_dict['rate'],data_dict['math'], color = 'r')
ax2.set_xlabel('Rate')
ax2.set_ylabel('Math')
plt.grid(True)

ax3 = fig.add_subplot(133)
plt.scatter(data_dict['verbal'],data_dict['math'], color = 'green')
ax3.set_xlabel('Verbal')
ax3.set_ylabel('Math')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 19. Are there any interesting relationships to note?

# %% [markdown]
# In order to further explore your data let's make some more plots. First overlay math and verbal v rate.

# %%
plt.scatter(data_dict['rate'],data_dict['math'], color = 'r', label='Math')
plt.scatter(data_dict['rate'],data_dict['verbal'], color = 'b', label='Verbal')
plt.xlabel('rate')
plt.title('correlation between math and verbal scores')
plt.grid(True)

plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# The Rate has a negative correlations with the Math and Verbal scores. What this means is that the more people that take the SAT the worse the average is.

# %% [markdown]
# Next, let's look again at the verbal v math.

# %%
plt.scatter(data_dict['verbal'],data_dict['math'], color = 'red')
plt.xlabel('Verbal')
plt.ylabel('Math')
plt.grid(True)
plt.show()

# %% [markdown]
# We see somethign interesting here: one state has a lot verbal and relative high math. well what state is that? It turns out to be ohio state. We don't have enought data to fully investigate unfortuantly.

# %% [markdown]
# ##### 20. Create box plots for each variable.

# %%
fig = plt.figure(figsize=(12,4))

ax1 = fig.add_subplot(131)
plt.boxplot(data_dict['rate'])
ax1.set_title('Box plot for Rate')

ax2 = fig.add_subplot(132)
plt.boxplot(data_dict['verbal'])
ax2.set_title('Box plot for Verbal')

ax3 = fig.add_subplot(133)
plt.boxplot(data_dict['math'])
ax3.set_title('Box plot for Math')
plt.show()

# %% [markdown]
# The box plot (a.k.a. box and whisker diagram) is a standardized way of displaying the distribution of data based on the five number summary: minimum, first quartile, median, third quartile, and maximum. I discussed this in detail in class.
#
# What we see here we really need to force the y-axis to be the same between math and verbal

# %%
fig = plt.figure(figsize=(12,4))

ax1 = fig.add_subplot(131)
plt.boxplot(data_dict['rate'])
ax1.set_title('Box plot for Rate')

ax2 = fig.add_subplot(132)
plt.boxplot(data_dict['verbal'])
ax2.set_ylim([400,650])
ax2.set_title('Box plot for Verbal')

ax3 = fig.add_subplot(133)
plt.boxplot(data_dict['math'])
ax3.set_ylim([400,650])
ax3.set_title('Box plot for Math')
plt.show()

# %% [markdown]
# ok now what we see is that math scores are much more disperse and slightly lower than verbal scores.

# %% [markdown]
# ## BONUS: Using Tableau, create a heat map for each variable using a map of the US.

# %%
from IPython.display import Image
Image(filename='./SAT_Verbal_Final.png')

# %%
Image(filename='./SAT_Math_Final.png')

# %% [markdown]
# I decided to not show Alaska and Hawaii
